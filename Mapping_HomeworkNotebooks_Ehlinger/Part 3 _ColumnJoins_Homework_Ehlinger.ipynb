# %% [markdown]
# # Number 3: Columns Joins
#
# You have two datasets:
#
# * An Excel document of obesity rates, called `obesity.xlsx`
# * A shapefile of US states from the [Census Burea](https://www.census.gov/geo/maps-data/data/tiger-cart-boundary.html), unzipped into `cb_2016_us_state_500k/`
#
# You're going to make a choropleth of obesity rates in US states.
#
# **MAKE SURE YOU HAVE COMPLETED PART TWO BEFORE YOU DO THIS ONE.**
#
# ## Part Zero: Import what you need
#
# I'm not giving you any more hints!

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# %matplotlib inline

# %% [markdown]
# ## Part One: Opening your datasets
#
# **Open up both files!** Think about what kind of file each one is before you try to open it.

# %%
obesity = pd.read_csv('obesity.csv')
obesity.columns
obesity
# Out:
#                statename   pct  Unnamed: 2  Unnamed: 3  Unnamed: 4
# 0                Alabama  31.1         NaN         NaN         NaN
# 1                 Alaska  27.7         NaN         NaN         NaN
# 2                Arizona  24.4         NaN         NaN         NaN
# 3               Arkansas  33.2         NaN         NaN         NaN
# 4             California  22.2         NaN         NaN         NaN
# 5               Colorado  19.1         NaN         NaN         NaN
# 6            Connecticut  24.0         NaN         NaN         NaN
# 7               Delaware  29.4         NaN         NaN         NaN
# 8   District of Columbia   9.9         NaN         NaN         NaN
# 9                Florida  25.2         NaN         NaN         NaN
# 10               Georgia  28.0         NaN         NaN         NaN
# 11                  Guam  21.1         NaN         NaN         NaN
# 12                Hawaii  17.9         NaN         NaN         NaN
# 13                 Idaho  28.1         NaN         NaN         NaN
# 14              Illinois  28.3         NaN         NaN         NaN
# 15               Indiana  31.3         NaN         NaN         NaN
# 16                  Iowa  31.6         NaN         NaN         NaN
# 17                Kansas  31.0         NaN         NaN         NaN
# 18              Kentucky  32.9         NaN         NaN         NaN
# 19             Louisiana  31.9         NaN         NaN         NaN
# 20                 Maine  29.2         NaN         NaN         NaN
# 21              Maryland  26.7         NaN         NaN         NaN
# 22         Massachusetts  23.0         NaN         NaN         NaN
# 23              Michigan  30.2         NaN         NaN         NaN
# 24             Minnesota  26.5         NaN         NaN         NaN
# 25           Mississippi  31.5         NaN         NaN         NaN
# 26              Missouri  30.4         NaN         NaN         NaN
# 27               Montana  23.8         NaN         NaN         NaN
# 28              Nebraska  30.0         NaN         NaN         NaN
# 29                Nevada  26.3         NaN         NaN         NaN
# 30         New Hampshire  27.3         NaN         NaN         NaN
# 31            New Jersey  25.6         NaN         NaN         NaN
# 32            New Mexico  22.8         NaN         NaN         NaN
# 33              New York  24.9         NaN         NaN         NaN
# 34        North Carolina  27.2         NaN         NaN         NaN
# 35          North Dakota  31.3         NaN         NaN         NaN
# 36                  Ohio  30.5         NaN         NaN         NaN
# 37              Oklahoma  32.5         NaN         NaN         NaN
# 38                Oregon  28.1         NaN         NaN         NaN
# 39          Pennsylvania  29.5         NaN         NaN         NaN
# 40           Puerto Rico  45.4         NaN         NaN         NaN
# 41          Rhode Island  26.4         NaN         NaN         NaN
# 42        South Carolina  28.3         NaN         NaN         NaN
# 43          South Dakota  29.6         NaN         NaN         NaN
# 44             Tennessee  31.5         NaN         NaN         NaN
# 45                 Texas  27.9         NaN         NaN         NaN
# 46                  Utah  24.5         NaN         NaN         NaN
# 47               Vermont  24.8         NaN         NaN         NaN
# 48              Virginia  26.7         NaN         NaN         NaN
# 49            Washington  27.7         NaN         NaN         NaN
# 50         West Virginia  35.2         NaN         NaN         NaN
# 51             Wisconsin  29.8         NaN         NaN         NaN
# 52               Wyoming  28.0         NaN         NaN         NaN

# %%
obesity.drop(obesity.columns[[2, 3, 4]], axis=1, inplace= True)
obesity.head()
# Out:
#     statename   pct
# 0     Alabama  31.1
# 1      Alaska  27.7
# 2     Arizona  24.4
# 3    Arkansas  33.2
# 4  California  22.2

# %%
#cb_2016_us_state_500k/
states = gpd.read_file('cb_2016_us_state_500k/')
states.head()
# Out:
#       AFFGEOID          ALAND        AWATER GEOID LSAD        NAME STATEFP  \
# 0  0400000US01   131173688951    4593686489    01   00     Alabama      01
# 1  0400000US02  1477946266785  245390495931    02   00      Alaska      02
# 2  0400000US04   294198560125    1027346486    04   00     Arizona      04
# 3  0400000US05   134771517596    2960191698    05   00    Arkansas      05
# 4  0400000US06   403501101370   20466718403    06   00  California      06
#
#     STATENS STUSPS                                           geometry
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 1  01785533     AK  (POLYGON ((-134.737262 58.261354, -134.73441 5...
# 2  01779777     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...
# 3  00068085     AR  POLYGON ((-94.6178329666013 36.4994141203285, ...
# 4  01779778     CA  (POLYGON ((-118.604415 33.478552, -118.598783 ...

# %%
states.crs
# Out:
# {'init': 'epsg:4269'}

# %% [markdown]
# ## Part Two: Map the states, just for fun
#
# To double-check that the states look okay, make a quick map of them.

# %%
#states = states.to_crs({'init': 'epsg:4326'})
states.plot(color ='grey', edgecolor='white', linewidth = 0.25, figsize = (20,15))

# %% [markdown]
# Uh, well, let's just stick to the continental Uninted States for now. An easy way to do this is by creating a **bounding box** and filtering out the ones that aren't inside.
#
# I like to use [this dumb site](https://itouchmap.com/latlong.html) to find the latitude and longitude of specific points, but if I'm just trying to figure out a box I use [geojson.io](http://geojson.io/) and just... draw a box and see what it tells me.
#
# For example, down below I am only selecting **the northeast**. I got the boundaries by drawing a box on geojson.io. We also use our good friend **`.within`** from last time to say hey states, which ones of you are inside of the boundary box?

# %%
from shapely.geometry import Polygon

bounds = [
            [
              -80.68359375,
              37.75334401310656
            ],
            [
              -65.91796875,
              37.75334401310656
            ],
            [
              -65.91796875,
              48.37084770238366
            ],
            [
              -80.68359375,
              48.37084770238366
            ],
            [
              -80.68359375,
              37.75334401310656
            ]
]

# Turn the coordinates into a shapely polygon
northeast_box = Polygon(bounds)

# Make sure our state CRS is in lat/lng by using to_crs
# You could also just have done
# states = states.to_crs({'init': 'epsg:4326'})
# and converted it permanently once instead of doing it multiple times later on
states.to_crs({'init': 'epsg:4326'}).within(northeast_box).head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# 9    False
# dtype: bool

# %% [markdown]
# And of course we can take those `True` and `False` values and feed them back into `states` to only get the states we're interested in. I plot them below, but you could always save them to a variable instead!

# %%
states[states.to_crs({'init': 'epsg:4326'}).within(northeast_box)].plot()

# %% [markdown]
# ## Part Three: Filter your states
#
# So *I* selected only states in the northeast. Now it's your job to use that new skill to **filter out any states that aren't in the continental USA.**

# %%
#states[states.to_crs({'init': 'epsg:4326'}).within(northeast_box)].plot()
states = states[~states.NAME.isin(['Hawaii', 'Alaska', 'Puerto Rico'])]
states.plot(color ='grey', edgecolor='white', linewidth = 0.25, figsize = (75,15))

# %% [markdown]
# ## Part Four: Joining your data
#
# You have some obesity data, it looks like this:

# %%
obesity.head(3)
# Out:
#   statename   pct
# 0   Alabama  31.1
# 1    Alaska  27.7
# 2   Arizona  24.4

# %% [markdown]
# You have some states, they look like this:

# %%
states.head(3)
# Out:
#       AFFGEOID         ALAND      AWATER GEOID LSAD      NAME STATEFP  \
# 0  0400000US01  131173688951  4593686489    01   00   Alabama      01
# 2  0400000US04  294198560125  1027346486    04   00   Arizona      04
# 3  0400000US05  134771517596  2960191698    05   00  Arkansas      05
#
#     STATENS STUSPS                                           geometry
# 0  01779775     AL  (POLYGON ((-88.053375 30.506987, -88.051087999...
# 2  01779777     AZ  POLYGON ((-114.816294 32.508038, -114.814321 3...
# 3  00068085     AR  POLYGON ((-94.6178329666013 36.4994141203285, ...

# %% [markdown]
# You need to **merge them together** using [merge](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.merge.html), which is just a normal pandas thing we've done before.
#
# **THIS IS NOT A SPATIAL JOIN.** We're just saying hey, you guys both have columns that match, right? You might want to get together.
#
# All `.merge` needs is two dataframes and a `left_on`/`right_on` to specify which columns to match up. Unlike a spatial join, for most column joins it doesn't matter which one is "left" and which one is "right."

# %%
obesity.merge(obesity,left_on='Name')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-9613fba49b49> in <module>()
# ----> 1 states.merge(obesity,left_on='Name')
#
# /usr/local/lib/python3.6/site-packages/geopandas/geodataframe.py in merge(self, *args, **kwargs)
#     394
#     395     def merge(self, *args, **kwargs):
# --> 396         result = DataFrame.merge(self, *args, **kwargs)
#     397         geo_col = self._geometry_column_name
#     398         if isinstance(result, DataFrame) and geo_col in result:
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#    4720                      right_on=right_on, left_index=left_index,
#    4721                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 4722                      copy=copy, indicator=indicator)
#    4723
#    4724     def round(self, decimals=0, *args, **kwargs):
#
# /usr/local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      51                          right_on=right_on, left_index=left_index,
#      52                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 53                          copy=copy, indicator=indicator)
#      54     return op.get_result()
#      55
#
# /usr/local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     551             warnings.warn(msg, UserWarning)
#     552
# --> 553         self._validate_specification()
#     554
#     555         # note this function has side effects
#
# /usr/local/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _validate_specification(self)
#     950                                      'of levels in the index of "left"')
#     951                 self.left_on = [None] * n
# --> 952         if len(self.right_on) != len(self.left_on):
#     953             raise ValueError("len(right_on) must equal len(left_on)")
#     954
#
# TypeError: object of type 'NoneType' has no len()

# %% [markdown]
# ## Part Five: Mapping your data
#
# Map it. Familiar projection, nice large size, etc. Use a [nice color map](https://matplotlib.org/examples/color/colormaps_reference.html) that makes sense.
#
# The one below is Mercator - you can see the grumpy top of the USA - see if you can make it something better! Maybe find the EPSG code for an Albers Equal Area that's good for the continental United States?

# %% [markdown]
# To get a different look, try passing `legend=True` and `scheme='Quantiles'`.

# %% [markdown]
# And oooone more time with `legend=True` and `scheme='equal_interval'`

# %% [markdown]
# ## Think about which one does the best job telling the story.
#
# We'll talk about this next class.
