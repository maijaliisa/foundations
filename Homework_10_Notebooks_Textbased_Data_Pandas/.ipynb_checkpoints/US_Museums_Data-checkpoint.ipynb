# %%
#Where did the dataset come from?

#I found the csv to download on Kaggle.com 

#If I had questions about this dataset, who would I ask?
#https://www.kaggle.com/imls/museum-directory

#Open the dataset using pandas.
#How many columns and rows does it have?
#Answered below 

#What are the data types of each column?
#answered below 

#Tell me what four of the columns mean, and state whether you made up the definitions or used a data dictionary.
#df.columns...made up the definitions 

#Write five questions you could ask the data. A simple way to ask decent questions is comparing a measurement across two subgroups. For example, "how do points scored in basketball in the 1950's compare to the 1990's," "how often do women punch walls vs. men punch walls?"
#1 - What city has the highest revenue-generating museums, zoos, etc.? 
#2 - can I add a column with city populations (requiring another dataset), and then compare per capita? 
#3 - compare the # of museums vs. zoos vs. art museums vs. science musuems etc. in each city 
#4 -

# %%
#This is working through pandas and downloading a fun CSV file of all of the museums in the USA 
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('museums.csv', error_bad_lines = False)
df.columns
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2683: DtypeWarning: Columns (9,14,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index(['Museum ID', 'Museum Name', 'Legal Name', 'Alternate Name',
#        'Museum Type', 'Institution Name',
#        'Street Address (Administrative Location)',
#        'City (Administrative Location)', 'State (Administrative Location)',
#        'Zip Code (Administrative Location)',
#        'Street Address (Physical Location)', 'City (Physical Location)',
#        'State (Physical Location)', 'Zip Code (Physical Location)',
#        'Phone Number', 'Latitude', 'Longitude', 'Locale Code (NCES)',
#        'County Code (FIPS)', 'State Code (FIPS)', 'Region Code (AAM)',
#        'Employer ID Number', 'Tax Period', 'Income', 'Revenue'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', 100)

# %%
df['State (Administrative Location)'].value_counts().head(10).plot(kind = 'barh')

# %%
df['Museum Type'].value_counts()
# Out:
# HISTORIC PRESERVATION                            14861
# GENERAL MUSEUM                                    8699
# ART MUSEUM                                        3241
# HISTORY MUSEUM                                    2284
# ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER     1484
# SCIENCE & TECHNOLOGY MUSEUM OR PLANETARIUM        1081
# ZOO, AQUARIUM, OR WILDLIFE CONSERVATION            564
# CHILDREN'S MUSEUM                                  512
# NATURAL HISTORY MUSEUM                             346
# Name: Museum Type, dtype: int64

# %%
df['Museum Type'].value_counts().plot(kind = 'barh')

# %%
df.shape
# Out:
# (33072, 25)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         Museum ID                                        Museum Name  \
# 0      8400200098                    ALASKA AVIATION HERITAGE MUSEUM
# 1      8400200117                            ALASKA BOTANICAL GARDEN
# 2      8400200153  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3      8400200143                ALASKA EDUCATORS HISTORICAL SOCIETY
# 4      8400200027                             ALASKA HERITAGE MUSEUM
# 5      8400200096                           ALASKA HISTORICAL MUSEUM
# 6      8400200078                               ALASKA JEWISH MUSEUM
# 7      8400200084                      ALASKA LIGHTHOUSE ASSOCIATION
# 8      8400200107       ALASKA MASONIC LIBRARY AND MUSEUM FOUNDATION
# 9      8400200073              ALASKA MINING HALL OF FAME FOUNDATION
# 10     8400200131    ALASKA NATIONAL GUARD HISTORICAL HOLDING-MUSEUM
# 11     8400200123                      ALASKA NATIVE HERITAGE CENTER
# ...

# %%
df['City (Administrative Location)'].value_counts().head(25)
# Out:
# NEW YORK         297
# WASHINGTON       228
# CHICAGO          194
# PHILADELPHIA     182
# LOS ANGELES      162
# PORTLAND         141
# HOUSTON          137
# BALTIMORE        122
# SAN FRANCISCO    119
# SPRINGFIELD      118
# RICHMOND         113
# COLUMBUS         111
# AUSTIN           104
# SEATTLE          103
# DALLAS           102
# SAN DIEGO         97
# BOSTON            95
# DENVER            90
# ATLANTA           90
# BROOKLYN          85
# PITTSBURGH        84
# LEXINGTON         83
# MADISON           83
# CLEVELAND         79
# LOUISVILLE        79
# Name: City (Administrative Location), dtype: int64

# %%
df.groupby('Museum Type')['City (Administrative Location)'].value_counts(dropna = False)
# Out:
# Museum Type                                    City (Administrative Location)
# ARBORETUM, BOTANICAL GARDEN, OR NATURE CENTER  WASHINGTON                        17
#                                                CHICAGO                           11
#                                                COLUMBUS                           8
#                                                DALLAS                             8
#                                                PHILADELPHIA                       8
#                                                SEATTLE                            8
#                                                NEW YORK                           7
#                                                BALTIMORE                          6
#                                                BATON ROUGE                        6
#                                                DAVIS                              6
# ...

# %%
#Figure this step out! 
df[df['City (Administrative Location)'] == 'Williamsport']
# Out:
# Empty DataFrame
# Columns: [Museum ID, Museum Name, Legal Name, Alternate Name, Museum Type, Institution Name, Street Address (Administrative Location), City (Administrative Location), State (Administrative Location), Zip Code (Administrative Location), Street Address (Physical Location), City (Physical Location), State (Physical Location), Zip Code (Physical Location), Phone Number, Latitude, Longitude, Locale Code (NCES), County Code (FIPS), State Code (FIPS), Region Code (AAM), Employer ID Number, Tax Period, Income, Revenue]
# Index: []
#
# [0 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['Museum ID', 'Museum Name', 'Legal Name', 'Alternate Name',
#        'Museum Type', 'Institution Name',
#        'Street Address (Administrative Location)',
#        'City (Administrative Location)', 'State (Administrative Location)',
#        'Zip Code (Administrative Location)',
#        'Street Address (Physical Location)', 'City (Physical Location)',
#        'State (Physical Location)', 'Zip Code (Physical Location)',
#        'Phone Number', 'Latitude', 'Longitude', 'Locale Code (NCES)',
#        'County Code (FIPS)', 'State Code (FIPS)', 'Region Code (AAM)',
#        'Employer ID Number', 'Tax Period', 'Income', 'Revenue'],
#       dtype='object')

# %%
df[['Museum ID', 'Museum Name', 'Museum Type', 'City (Administrative Location)', 'Zip Code (Physical Location)', 'Income', 'Revenue']]
# Out:
#         Museum ID                                        Museum Name  \
# 0      8400200098                    ALASKA AVIATION HERITAGE MUSEUM
# 1      8400200117                            ALASKA BOTANICAL GARDEN
# 2      8400200153  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3      8400200143                ALASKA EDUCATORS HISTORICAL SOCIETY
# 4      8400200027                             ALASKA HERITAGE MUSEUM
# 5      8400200096                           ALASKA HISTORICAL MUSEUM
# 6      8400200078                               ALASKA JEWISH MUSEUM
# 7      8400200084                      ALASKA LIGHTHOUSE ASSOCIATION
# 8      8400200107       ALASKA MASONIC LIBRARY AND MUSEUM FOUNDATION
# 9      8400200073              ALASKA MINING HALL OF FAME FOUNDATION
# 10     8400200131    ALASKA NATIONAL GUARD HISTORICAL HOLDING-MUSEUM
# 11     8400200123                      ALASKA NATIVE HERITAGE CENTER
# 12     8409500006                              ALASKA SEALIFE CENTER
# ...

# %%
df['City (Administrative Location)'].str.contains("^ATL", na=False).value_counts()
# Out:
# False    32970
# True       102
# Name: City (Administrative Location), dtype: int64

# %%
df['City (Administrative Location)'].str.contains("NEW YORK").value_counts()
# Out:
# False    32767
# True       305
# Name: City (Administrative Location), dtype: int64

# %%
df['City (Administrative Location)'].str.contains("THOUSAND OAKS").value_counts()
# Out:
# False    33066
# True         6
# Name: City (Administrative Location), dtype: int64

# %%
df['Zip Code (Physical Location)'].astype(float)
df['Zip Code (Physical Location)'].str.contains(30308, na=False).value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-6c932b96e487> in <module>()
#       1 df['Zip Code (Physical Location)'].astype(float)
# ----> 2 df['Zip Code (Physical Location)'].str.contains(30308, na=False).value_counts()
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3075         if (name in self._internal_names_set or name in self._metadata or
#    3076                 name in self._accessors):
# -> 3077             return object.__getattribute__(self, name)
#    3078         else:
#    3079             if name in self._info_axis:
#
# /usr/local/lib/python3.6/site-packages/pandas/core/base.py in __get__(self, instance, owner)
#     241             # this ensures that Series.str.<method> is well defined
#     242             return self.accessor_cls
# ...
