# %% [markdown]
# # Exercise: Cherry Blossoms!
#
# #### Summary
#
# Once upon a time it was サクラ season, which meant the [cherry blossoms](https://en.wikipedia.org/wiki/Cherry_blossom) were in full bloom! This year they bloomed a little early and they've long sinced faded, so for today we'll stick with data-driven blossoms: http://atmenv.envi.osakafu-u.ac.jp/aono/kyophenotemp4/
#
# #### Data Source(s)
#
# Historical Series of Phenological data for Cherry Tree Flowering at Kyoto City
# (and March Mean Temperature Reconstructions), http://atmenv.envi.osakafu-u.ac.jp/aono/kyophenotemp4/
#
# #### Files
#
# - KyotoFullFlower7.xls, "Full-flowering Dates of Prunus jamasakura in Kyoto City"
#
# #### Skills
#
# - Working with Excel files
# - Ignoring the first few rows
# - Replacing NaN values
# - Counting and summarizing columns
# - Replacing non-NaN values
# - Extracting with strings
# - Rolling means

# %% [markdown]
# # Read in `KyotoFullFlower7.xls`
#
# Be sure to look at the first five rows.

# %%
import pandas as pd
df = pd.read_excel('KyotoFullFlower7.xls', error_bad_line = False)
df.head(5)
# Out:
#   Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)  \
# 0  This phenological data was acquired by followi...
# 1                                                NaN
# 2                                     Column A; A.D.
# 3       Column B; Full-flowering date (day of year).
# 4  Column C; Full-flowering date (calender date, ...
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN

# %% [markdown]
# ### That... doesn't look right. Why not?
#
# Examine your column names, and maybe even open up the file in Excel.

# %%
#the first columns are information about the data set

# %% [markdown]
# ### Read in the file correctly, and look at the first five rows
#
# - TIP: The first year should be 801 AD, and it should not have any dates or anything.

# %%
df = pd.read_excel('KyotoFullFlower7.xls', error_bad_line = False, skiprows = 25)
df.head()
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#    Data type code Reference Name
# 0             NaN              -
# 1             NaN              -
# 2             NaN              -
# 3             NaN              -
# 4             NaN              -

# %% [markdown]
# ### Look at the final five rows of the data

# %%
df.tail()
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code          Reference Name
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# ## Watching out for NaN values

# %% [markdown]
# Take a look at **Reference name**. Is there something you should set to be `NaN`? Use either of the two ways we have covered.

# %%
df['Reference Name'].isnull().value_counts()
df.head(25)
# Out:
#      AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0   801                        NaN                  NaN          NaN
# 1   802                        NaN                  NaN          NaN
# 2   803                        NaN                  NaN          NaN
# 3   804                        NaN                  NaN          NaN
# 4   805                        NaN                  NaN          NaN
# 5   806                        NaN                  NaN          NaN
# 6   807                        NaN                  NaN          NaN
# 7   808                        NaN                  NaN          NaN
# 8   809                        NaN                  NaN          NaN
# 9   810                        NaN                  NaN          NaN
# 10  811                        NaN                  NaN          NaN
# 11  812                       92.0                401.0          1.0
# 12  813                        NaN                  NaN          NaN
# 13  814                        NaN                  NaN          NaN
# 14  815                      105.0                415.0          1.0
# 15  816                        NaN                  NaN          NaN
# 16  817                        NaN                  NaN          NaN
# 17  818                        NaN                  NaN          NaN
# 18  819                        NaN                  NaN          NaN
# 19  820                        NaN                  NaN          NaN
# 20  821                        NaN                  NaN          NaN
# 21  822                        NaN                  NaN          NaN
# 22  823                        NaN                  NaN          NaN
# 23  824                        NaN                  NaN          NaN
# 24  825                        NaN                  NaN          NaN
#
#     Data type code Reference Name
# 0              NaN              -
# 1              NaN              -
# 2              NaN              -
# 3              NaN              -
# 4              NaN              -
# 5              NaN              -
# 6              NaN              -
# 7              NaN              -
# 8              NaN              -
# 9              NaN              -
# 10             NaN              -
# 11             2.0     NIHON-KOKI
# 12             NaN              -
# 13             NaN              -
# 14             2.0     NIHON-KOKI
# 15             NaN              -
# 16             NaN              -
# 17             NaN              -
# 18             NaN              -
# 19             NaN              -
# 20             NaN              -
# 21             NaN              -
# 22             NaN              -
# 23             NaN              -
# 24             NaN              -

# %% [markdown]
# ### Check that you have 827 values for "Full-flowering date (DOY)" and 825 for "Reference Name"

# %%
df = df.dropna(axis=0, how='any')

# %%
#825 rows with reference names and DOYs 
df.shape
# Out:
# (825, 6)

# %% [markdown]
# # Cleaning up our data

# %% [markdown]
# ## What sources are the most common as a reference?

# %%
df['Reference Name'].value_counts().head()
# Out:
# NEWS-PAPER(ARASHIYAMA)    94
# SUGIURAKE-NIKKI           38
# MYOHOIN-HINAMIKI          32
# OYUDONONO-UENO-NIKKI      26
# DAIGOJI-ZATSUYO           21
# Name: Reference Name, dtype: int64

# %% [markdown]
# ## Filter the list to only include rows that have a `Full-flowering date (DOY)`

# %%
df.dtypes
# Out:
# AD                             int64
# Full-flowering date (DOY)    float64
# Full-flowering date          float64
# Source code                  float64
# Data type code               float64
# Reference Name                object
# dtype: object

# %%
#I tried this with numpy and I couldn't figure out how to save it back into the dataframe without the NaNs
#import numpy as np
#df['Full-flowering date (DOY)'].replace('NaN', np.nan, inplace = True)

# %%
#df['Full-flowering date (DOY)'].astype(float)
#df['Full-flowering date (DOY)'].str.contains("^\d\d", na=False)
df['Full-flowering date (DOY)'].dropna().head(10)
# Out:
# 11     92.0
# 14    105.0
# 30     96.0
# 50    108.0
# 52    104.0
# 63    100.0
# 65    106.0
# 68     95.0
# 88    104.0
# 90    109.0
# Name: Full-flowering date (DOY), dtype: float64

# %%
#This method of dropna(axis=0) seems to work better than 
df = df.dropna(axis=0, how='any')
df
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11     812                       92.0                401.0          1.0
# 14     815                      105.0                415.0          1.0
# 30     831                       96.0                406.0          1.0
# 50     851                      108.0                418.0          1.0
# 52     853                      104.0                414.0          1.0
# 63     864                      100.0                409.0          1.0
# 65     866                      106.0                416.0          1.0
# 68     869                       95.0                405.0          5.0
# 88     889                      104.0                414.0          5.0
# 90     891                      109.0                419.0          5.0
# 91     892                      108.0                417.0          5.0
# 93     894                      106.0                416.0          5.0
# 94     895                      104.0                414.0          5.0
# 95     896                      104.0                413.0          5.0
# 101    902                      102.0                412.0          5.0
# 107    908                       98.0                407.0          5.0
# 111    912                       95.0                404.0          1.0
# 112    913                      110.0                420.0          5.0
# 116    917                       95.0                405.0          1.0
# 122    923                      104.0                414.0          5.0
# 125    926                       98.0                408.0          1.0
# 129    930                       97.0                407.0          5.0
# 132    933                      106.0                416.0          5.0
# 140    941                      109.0                419.0          1.0
# 148    949                      107.0                417.0          1.0
# 149    950                       95.0                405.0          4.0
# 154    955                       89.0                330.0          5.0
# 156    957                      112.0                422.0          1.0
# 157    958                      109.0                419.0          1.0
# 158    959                       97.0                407.0          3.0
# ...    ...                        ...                  ...          ...
# 1185  1986                      102.0                412.0          3.0
# 1186  1987                       95.0                405.0          3.0
# 1187  1988                      106.0                415.0          3.0
# 1188  1989                       93.0                403.0          3.0
# 1189  1990                       88.0                329.0          3.0
# 1190  1991                       97.0                407.0          4.0
# 1191  1992                       94.0                403.0          4.0
# 1192  1993                       97.0                407.0          4.0
# 1193  1994                       99.0                409.0          4.0
# 1194  1995                       99.0                409.0          4.0
# 1195  1996                      103.0                412.0          4.0
# 1196  1997                       97.0                407.0          4.0
# 1197  1998                       91.0                401.0          4.0
# 1198  1999                       94.0                404.0          4.0
# 1199  2000                      100.0                409.0          4.0
# 1200  2001                       96.0                406.0          4.0
# 1201  2002                       91.0                401.0          4.0
# 1202  2003                       98.0                408.0          4.0
# 1203  2004                       92.0                401.0          4.0
# 1204  2005                       99.0                409.0          4.0
# 1205  2006                       98.0                408.0          5.0
# 1206  2007                       97.0                407.0          5.0
# 1207  2008                       95.0                404.0          6.0
# 1208  2009                       95.0                405.0          6.0
# 1209  2010                       95.0                405.0          7.0
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code              Reference Name
# 11               2.0                  NIHON-KOKI
# 14               2.0                  NIHON-KOKI
# 30               2.0                  NIHON-KOKI
# 50               2.0      MONTOKUTENNO-JITSUROKU
# 52               2.0      MONTOKUTENNO-JITSUROKU
# 63               2.0     NIPPON-SANDAI-JITSUROKU
# 65               2.0     NIPPON-SANDAI-JITSUROKU
# 68               2.0                KANKE-BUNSOU
# 88               2.0     NIPPON-SANDAI-JITSUROKU
# 90               4.0                NIHONKIRYAKU
# 91               3.0         FUSHIMIIN-GOKIROKKU
# 93               2.0                KANKE-BUNSOU
# 94               4.0                NIHONKIRYAKU
# 95               4.0     NIPPON-SANDAI-JITSUROKU
# 101              8.0  EST-from-WF(NIHONGI-RYAKU)
# 107              8.0   EST-from-WF(KIMITADA-SHU)
# 111              2.0                 SHINGISHIKI
# 112              2.0                SHUI-WAKASHU
# 116              2.0                    KINHISHO
# 122              4.0          ZOKU-KOKIN-WAKASHU
# 125              2.0                NIHONKIRYAKU
# 129              8.0   EST-from-WF(SHIRYO-SORAN)
# 132              8.0   EST-from-WF(SHIRYO-SORAN)
# 140              2.0                NIHONKIRYAKU
# 148              2.0                NIHONKIRYAKU
# 149              2.0             DAINIHON-SHIRYO
# 154              4.0                     SHUISHO
# 156              2.0                NIHONKIRYAKU
# 157              2.0                NIHONKIRYAKU
# 158              2.0                     KYUREKI
# ...              ...                         ...
# 1185             0.0      NEWS-PAPER(ARASHIYAMA)
# 1186             0.0      NEWS-PAPER(ARASHIYAMA)
# 1187             0.0      NEWS-PAPER(ARASHIYAMA)
# 1188             0.0      NEWS-PAPER(ARASHIYAMA)
# 1189             0.0      NEWS-PAPER(ARASHIYAMA)
# 1190             0.0      NEWS-PAPER(ARASHIYAMA)
# 1191             0.0      NEWS-PAPER(ARASHIYAMA)
# 1192             0.0      NEWS-PAPER(ARASHIYAMA)
# 1193             0.0      NEWS-PAPER(ARASHIYAMA)
# 1194             0.0      NEWS-PAPER(ARASHIYAMA)
# 1195             0.0      NEWS-PAPER(ARASHIYAMA)
# 1196             0.0      NEWS-PAPER(ARASHIYAMA)
# 1197             0.0      NEWS-PAPER(ARASHIYAMA)
# 1198             0.0      NEWS-PAPER(ARASHIYAMA)
# 1199             0.0      NEWS-PAPER(ARASHIYAMA)
# 1200             0.0      NEWS-PAPER(ARASHIYAMA)
# 1201             0.0      NEWS-PAPER(ARASHIYAMA)
# 1202             0.0      NEWS-PAPER(ARASHIYAMA)
# 1203             0.0      NEWS-PAPER(ARASHIYAMA)
# 1204             0.0      NEWS-PAPER(ARASHIYAMA)
# 1205             0.0      NEWS-PAPER(ARASHIYAMA)
# 1206             0.0      NEWS-PAPER(ARASHIYAMA)
# 1207             0.0      NEWS-PAPER(ARASHIYAMA)
# 1208             0.0      NEWS-PAPER(ARASHIYAMA)
# 1209             0.0      NEWS-PAPER(ARASHIYAMA)
# 1210             0.0      NEWS-PAPER(ARASHIYAMA)
# 1211             0.0      NEWS-PAPER(ARASHIYAMA)
# 1212             0.0      NEWS-PAPER(ARASHIYAMA)
# 1213             0.0      NEWS-PAPER(ARASHIYAMA)
# 1214             0.0      NEWS-PAPER(ARASHIYAMA)
#
# [825 rows x 6 columns]

# %% [markdown]
# ## Make a histogram of the full-flowering date.

# %%
# %matplotlib inline
df['Full-flowering date (DOY)'].hist()

# %% [markdown]
# ## Make another histogram of the full-flowering date, but with 39 bins instead of 10

# %%
df['Full-flowering date (DOY)'].hist(bins=39)

# %% [markdown]
# ## What's the average number of days it takes for the flowers to blossom? The max? Min? And how many records do we have?
#
# Answer these with one line of code.

# %%
import statistics
df.columns
# Out:
# Index(['AD', 'Full-flowering date (DOY)', 'Full-flowering date', 'Source code',
#        'Data type code', 'Reference Name'],
#       dtype='object')

# %%
df['Full-flowering date (DOY)'].describe()
# Out:
# count    825.000000
# mean     104.556364
# std        6.394554
# min       86.000000
# 25%      100.000000
# 50%      105.000000
# 75%      109.000000
# max      124.000000
# Name: Full-flowering date (DOY), dtype: float64

# %%
df['Full-flowering date'].describe()
# Out:
# count    825.000000
# mean     413.816970
# std       12.048313
# min      327.000000
# 25%      410.000000
# 50%      414.000000
# 75%      419.000000
# max      504.000000
# Name: Full-flowering date, dtype: float64

# %% [markdown]
# ## What's the average number of days into the year cherry flowers normally blossomed before 1900?

# %%
df[df['AD'] > 1900]['Full-flowering date (DOY)'].mean()
# Out:
# 100.3125

# %% [markdown]
# ## How about after 1900?

# %%
#line for year 1900 starts at 1189 ...but don't need that because you can just just do the mean on different columns 
df[df['AD'] < 1900]['Full-flowering date (DOY)'].mean()
# Out:
# 105.22752808988764

# %% [markdown]
# ## How many times was our data from a title in Japanese poetry?
#
# You'll need to read the documentation inside of the Excel file.

# %%
#data type code = 4 (from documentation information on the Excel file)

# %%
df['Data type code'].value_counts()
#so 39 of them came from poetry sources
# Out:
# 2.0    452
# 1.0    166
# 0.0    124
# 4.0     39
# 3.0     30
# 8.0     11
# 9.0      3
# Name: Data type code, dtype: int64

# %% [markdown]
# ## Actually, that looks terrible. Replace the "Source code" and "data type code" columns with the values they stand for.

# %%
#Column E; Data type code	
# 0 : data from modern times (full-bloom date since 1880s)	
# 1 : from diary description about full-bloom	
# 2 : from diary description about cherry blossom viewing party	
# 3 : from diary description about presents of cherry twigs from party participants	
# 4 : title in Japanese poety	
# 8 : Deduced from wisteria phenology, using the relation proposed by Aono and Saito (2010)	
# 9 : Deduced from Japanese kerria phenology, using the relation proposed by Aono (2011)

# %%
replacements = {
    0: "data from modern times",
    1: "diary description",
    2: "diary description about viewing party",
    3: "diary description about cherry twigs",
    4: "Japanese poetry",
    8: "deduced from wisteria phenology",
    9: "deduced from kerria phenology"    
}

df['Data type code'].replace(replacements, inplace = True) 
df.head(25)
# Out:
#       AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11   812                       92.0                401.0          1.0
# 14   815                      105.0                415.0          1.0
# 30   831                       96.0                406.0          1.0
# 50   851                      108.0                418.0          1.0
# 52   853                      104.0                414.0          1.0
# 63   864                      100.0                409.0          1.0
# 65   866                      106.0                416.0          1.0
# 68   869                       95.0                405.0          5.0
# 88   889                      104.0                414.0          5.0
# 90   891                      109.0                419.0          5.0
# 91   892                      108.0                417.0          5.0
# 93   894                      106.0                416.0          5.0
# 94   895                      104.0                414.0          5.0
# 95   896                      104.0                413.0          5.0
# 101  902                      102.0                412.0          5.0
# 107  908                       98.0                407.0          5.0
# 111  912                       95.0                404.0          1.0
# 112  913                      110.0                420.0          5.0
# 116  917                       95.0                405.0          1.0
# 122  923                      104.0                414.0          5.0
# 125  926                       98.0                408.0          1.0
# 129  930                       97.0                407.0          5.0
# 132  933                      106.0                416.0          5.0
# 140  941                      109.0                419.0          1.0
# 148  949                      107.0                417.0          1.0
#
#                             Data type code              Reference Name
# 11   diary description about viewing party                  NIHON-KOKI
# 14   diary description about viewing party                  NIHON-KOKI
# 30   diary description about viewing party                  NIHON-KOKI
# 50   diary description about viewing party      MONTOKUTENNO-JITSUROKU
# 52   diary description about viewing party      MONTOKUTENNO-JITSUROKU
# 63   diary description about viewing party     NIPPON-SANDAI-JITSUROKU
# 65   diary description about viewing party     NIPPON-SANDAI-JITSUROKU
# 68   diary description about viewing party                KANKE-BUNSOU
# 88   diary description about viewing party     NIPPON-SANDAI-JITSUROKU
# 90                         Japanese poetry                NIHONKIRYAKU
# 91    diary description about cherry twigs         FUSHIMIIN-GOKIROKKU
# 93   diary description about viewing party                KANKE-BUNSOU
# 94                         Japanese poetry                NIHONKIRYAKU
# 95                         Japanese poetry     NIPPON-SANDAI-JITSUROKU
# 101        deduced from wisteria phenology  EST-from-WF(NIHONGI-RYAKU)
# 107        deduced from wisteria phenology   EST-from-WF(KIMITADA-SHU)
# 111  diary description about viewing party                 SHINGISHIKI
# 112  diary description about viewing party                SHUI-WAKASHU
# 116  diary description about viewing party                    KINHISHO
# 122                        Japanese poetry          ZOKU-KOKIN-WAKASHU
# 125  diary description about viewing party                NIHONKIRYAKU
# 129        deduced from wisteria phenology   EST-from-WF(SHIRYO-SORAN)
# 132        deduced from wisteria phenology   EST-from-WF(SHIRYO-SORAN)
# 140  diary description about viewing party                NIHONKIRYAKU
# 148  diary description about viewing party                NIHONKIRYAKU

# %%
df.columns
# Out:
# Index(['AD', 'Full-flowering date (DOY)', 'Full-flowering date', 'Source code',
#        'Data type code', 'Reference Name'],
#       dtype='object')

# %%
#Column D; Source code		
# 1; Reported by Taguchi (1939), J. Marine Meteorol. Soc. (Umi to Sora), 19, 217-227		
# 2; Added by Sekiguchi (1969), Tokyo Geography Papers, 13, 175-190.		
# 3; Added by Aono and Omoto (1994), J. Agric. Meteorol., 49, 263-272.		
# 4; Added by Aono and Kazui (2008), Int. J. Climatol., 28, 905-914 (doi: 10.1002/joc.1594).		
# 5: Cherry phenological data, Added by Aono and Saito (2010), Int. J. Biometeorol., 54, 211-219.		
# 6: Added by Aono (2011), Time Studies, 4, 17-29. (in Japanese with English abstract)		
# 7: Added by Aono (2012), Chikyu Kankyo, 17, 21-29. (in Japanese)		
# 8: Found after the last publication of articles.

# %%
replacements_2 = {
    1: "Reported by Taguchi (1939)",
    2: "Added by Sekiguchi (1969)",
    3: "Added by Aono and Omoto (1994)",
    4: "Added by Aono and Kazui (2008)",
    5: "Cherry phenological data, Added by Aono and Saito (2010)",
    6: "Added by Aono (2011)",
    7: "Added by Aono (2012)",
    8: "ound after the last publication of articles"
}

df['Source code'].replace(replacements_2, inplace=True)
df
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  \
# 11     812                       92.0                401.0
# 14     815                      105.0                415.0
# 30     831                       96.0                406.0
# 50     851                      108.0                418.0
# 52     853                      104.0                414.0
# 63     864                      100.0                409.0
# 65     866                      106.0                416.0
# 68     869                       95.0                405.0
# 88     889                      104.0                414.0
# 90     891                      109.0                419.0
# 91     892                      108.0                417.0
# 93     894                      106.0                416.0
# 94     895                      104.0                414.0
# 95     896                      104.0                413.0
# 101    902                      102.0                412.0
# 107    908                       98.0                407.0
# 111    912                       95.0                404.0
# 112    913                      110.0                420.0
# 116    917                       95.0                405.0
# 122    923                      104.0                414.0
# 125    926                       98.0                408.0
# 129    930                       97.0                407.0
# 132    933                      106.0                416.0
# 140    941                      109.0                419.0
# 148    949                      107.0                417.0
# 149    950                       95.0                405.0
# 154    955                       89.0                330.0
# 156    957                      112.0                422.0
# 157    958                      109.0                419.0
# 158    959                       97.0                407.0
# ...    ...                        ...                  ...
# 1185  1986                      102.0                412.0
# 1186  1987                       95.0                405.0
# 1187  1988                      106.0                415.0
# 1188  1989                       93.0                403.0
# 1189  1990                       88.0                329.0
# 1190  1991                       97.0                407.0
# 1191  1992                       94.0                403.0
# 1192  1993                       97.0                407.0
# 1193  1994                       99.0                409.0
# 1194  1995                       99.0                409.0
# 1195  1996                      103.0                412.0
# 1196  1997                       97.0                407.0
# 1197  1998                       91.0                401.0
# 1198  1999                       94.0                404.0
# 1199  2000                      100.0                409.0
# 1200  2001                       96.0                406.0
# 1201  2002                       91.0                401.0
# 1202  2003                       98.0                408.0
# 1203  2004                       92.0                401.0
# 1204  2005                       99.0                409.0
# 1205  2006                       98.0                408.0
# 1206  2007                       97.0                407.0
# 1207  2008                       95.0                404.0
# 1208  2009                       95.0                405.0
# 1209  2010                       95.0                405.0
# 1210  2011                       99.0                409.0
# 1211  2012                      101.0                410.0
# 1212  2013                       93.0                403.0
# 1213  2014                       94.0                404.0
# 1214  2015                       93.0                403.0
#
#                                             Source code  \
# 11                           Reported by Taguchi (1939)
# 14                           Reported by Taguchi (1939)
# 30                           Reported by Taguchi (1939)
# 50                           Reported by Taguchi (1939)
# 52                           Reported by Taguchi (1939)
# 63                           Reported by Taguchi (1939)
# 65                           Reported by Taguchi (1939)
# 68    Cherry phenological data, Added by Aono and Sa...
# 88    Cherry phenological data, Added by Aono and Sa...
# 90    Cherry phenological data, Added by Aono and Sa...
# 91    Cherry phenological data, Added by Aono and Sa...
# 93    Cherry phenological data, Added by Aono and Sa...
# 94    Cherry phenological data, Added by Aono and Sa...
# 95    Cherry phenological data, Added by Aono and Sa...
# 101   Cherry phenological data, Added by Aono and Sa...
# 107   Cherry phenological data, Added by Aono and Sa...
# 111                          Reported by Taguchi (1939)
# 112   Cherry phenological data, Added by Aono and Sa...
# 116                          Reported by Taguchi (1939)
# 122   Cherry phenological data, Added by Aono and Sa...
# 125                          Reported by Taguchi (1939)
# 129   Cherry phenological data, Added by Aono and Sa...
# 132   Cherry phenological data, Added by Aono and Sa...
# 140                          Reported by Taguchi (1939)
# 148                          Reported by Taguchi (1939)
# 149                      Added by Aono and Kazui (2008)
# 154   Cherry phenological data, Added by Aono and Sa...
# 156                          Reported by Taguchi (1939)
# 157                          Reported by Taguchi (1939)
# 158                      Added by Aono and Omoto (1994)
# ...                                                 ...
# 1185                     Added by Aono and Omoto (1994)
# 1186                     Added by Aono and Omoto (1994)
# 1187                     Added by Aono and Omoto (1994)
# 1188                     Added by Aono and Omoto (1994)
# 1189                     Added by Aono and Omoto (1994)
# 1190                     Added by Aono and Kazui (2008)
# 1191                     Added by Aono and Kazui (2008)
# 1192                     Added by Aono and Kazui (2008)
# 1193                     Added by Aono and Kazui (2008)
# 1194                     Added by Aono and Kazui (2008)
# 1195                     Added by Aono and Kazui (2008)
# 1196                     Added by Aono and Kazui (2008)
# 1197                     Added by Aono and Kazui (2008)
# 1198                     Added by Aono and Kazui (2008)
# 1199                     Added by Aono and Kazui (2008)
# 1200                     Added by Aono and Kazui (2008)
# 1201                     Added by Aono and Kazui (2008)
# 1202                     Added by Aono and Kazui (2008)
# 1203                     Added by Aono and Kazui (2008)
# 1204                     Added by Aono and Kazui (2008)
# 1205  Cherry phenological data, Added by Aono and Sa...
# 1206  Cherry phenological data, Added by Aono and Sa...
# 1207                               Added by Aono (2011)
# 1208                               Added by Aono (2011)
# 1209                               Added by Aono (2012)
# 1210        ound after the last publication of articles
# 1211        ound after the last publication of articles
# 1212        ound after the last publication of articles
# 1213        ound after the last publication of articles
# 1214        ound after the last publication of articles
#
#                              Data type code              Reference Name
# 11    diary description about viewing party                  NIHON-KOKI
# 14    diary description about viewing party                  NIHON-KOKI
# 30    diary description about viewing party                  NIHON-KOKI
# 50    diary description about viewing party      MONTOKUTENNO-JITSUROKU
# 52    diary description about viewing party      MONTOKUTENNO-JITSUROKU
# 63    diary description about viewing party     NIPPON-SANDAI-JITSUROKU
# 65    diary description about viewing party     NIPPON-SANDAI-JITSUROKU
# 68    diary description about viewing party                KANKE-BUNSOU
# 88    diary description about viewing party     NIPPON-SANDAI-JITSUROKU
# 90                          Japanese poetry                NIHONKIRYAKU
# 91     diary description about cherry twigs         FUSHIMIIN-GOKIROKKU
# 93    diary description about viewing party                KANKE-BUNSOU
# 94                          Japanese poetry                NIHONKIRYAKU
# 95                          Japanese poetry     NIPPON-SANDAI-JITSUROKU
# 101         deduced from wisteria phenology  EST-from-WF(NIHONGI-RYAKU)
# 107         deduced from wisteria phenology   EST-from-WF(KIMITADA-SHU)
# 111   diary description about viewing party                 SHINGISHIKI
# 112   diary description about viewing party                SHUI-WAKASHU
# 116   diary description about viewing party                    KINHISHO
# 122                         Japanese poetry          ZOKU-KOKIN-WAKASHU
# 125   diary description about viewing party                NIHONKIRYAKU
# 129         deduced from wisteria phenology   EST-from-WF(SHIRYO-SORAN)
# 132         deduced from wisteria phenology   EST-from-WF(SHIRYO-SORAN)
# 140   diary description about viewing party                NIHONKIRYAKU
# 148   diary description about viewing party                NIHONKIRYAKU
# 149   diary description about viewing party             DAINIHON-SHIRYO
# 154                         Japanese poetry                     SHUISHO
# 156   diary description about viewing party                NIHONKIRYAKU
# 157   diary description about viewing party                NIHONKIRYAKU
# 158   diary description about viewing party                     KYUREKI
# ...                                     ...                         ...
# 1185                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1186                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1187                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1188                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1189                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1190                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1191                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1192                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1193                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1194                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1195                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1196                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1197                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1198                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1199                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1200                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1201                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1202                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1203                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1204                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1205                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1206                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1207                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1208                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1209                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1210                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1211                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1212                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1213                 data from modern times      NEWS-PAPER(ARASHIYAMA)
# 1214                 data from modern times      NEWS-PAPER(ARASHIYAMA)
#
# [825 rows x 6 columns]

# %% [markdown]
# ## Show only the years where our data was from a title in Japanese poetry

# %%
df[df['Data type code'].str.contains(".*poetry")]
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  \
# 90     891                      109.0                419.0
# 94     895                      104.0                414.0
# 95     896                      104.0                413.0
# 122    923                      104.0                414.0
# 154    955                       89.0                330.0
# 168    969                       98.0                408.0
# 206   1007                      106.0                416.0
# 232   1033                      102.0                412.0
# 235   1036                      104.0                413.0
# 259   1060                      108.0                417.0
# 260   1061                       92.0                402.0
# 283   1084                      120.0                429.0
# 294   1095                      100.0                410.0
# 381   1182                      104.0                414.0
# 389   1190                      112.0                422.0
# 400   1201                       96.0                406.0
# 415   1216                      101.0                410.0
# 418   1219                      101.0                411.0
# 420   1221                       99.0                409.0
# 422   1223                      116.0                426.0
# 435   1236                       87.0                327.0
# 464   1265                       98.0                408.0
# 467   1268                      103.0                412.0
# 468   1269                      100.0                410.0
# 470   1271                      100.0                410.0
# 488   1289                      107.0                417.0
# 500   1301                       95.0                405.0
# 523   1324                       98.0                407.0
# 529   1330                      108.0                418.0
# 646   1447                      111.0                421.0
# 652   1453                      107.0                417.0
# 653   1454                      105.0                415.0
# 673   1474                       98.0                408.0
# 733   1534                      108.0                418.0
# 791   1592                       98.0                407.0
# 839   1640                      103.0                412.0
# 860   1661                       93.0                403.0
# 1045  1846                       98.0                408.0
# 1062  1863                      118.0                428.0
#
#                                             Source code   Data type code  \
# 90    Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 94    Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 95    Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 122   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 154   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 168   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 206   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 232   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 235   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 259   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 260                                Added by Aono (2011)  Japanese poetry
# 283   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 294   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 381                                Added by Aono (2011)  Japanese poetry
# 389   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 400   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 415   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 418   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 420   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 422   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 435                                Added by Aono (2012)  Japanese poetry
# 464                                Added by Aono (2011)  Japanese poetry
# 467                                Added by Aono (2011)  Japanese poetry
# 468                      Added by Aono and Omoto (1994)  Japanese poetry
# 470   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 488                      Added by Aono and Omoto (1994)  Japanese poetry
# 500                      Added by Aono and Kazui (2008)  Japanese poetry
# 523   Cherry phenological data, Added by Aono and Sa...  Japanese poetry
# 529                                Added by Aono (2012)  Japanese poetry
# 646                      Added by Aono and Omoto (1994)  Japanese poetry
# 652                      Added by Aono and Omoto (1994)  Japanese poetry
# 653                      Added by Aono and Omoto (1994)  Japanese poetry
# 673                      Added by Aono and Omoto (1994)  Japanese poetry
# 733                      Added by Aono and Omoto (1994)  Japanese poetry
# 791                      Added by Aono and Kazui (2008)  Japanese poetry
# 839                      Added by Aono and Omoto (1994)  Japanese poetry
# 860                                Added by Aono (2012)  Japanese poetry
# 1045                     Added by Aono and Kazui (2008)  Japanese poetry
# 1062                     Added by Aono and Kazui (2008)  Japanese poetry
#
#                   Reference Name
# 90                  NIHONKIRYAKU
# 94                  NIHONKIRYAKU
# 95       NIPPON-SANDAI-JITSUROKU
# 122           ZOKU-KOKIN-WAKASHU
# 154                      SHUISHO
# 168                 NIHONKIRYAKU
# 206               MIDO-KAMPAKUKI
# 232                 NIHONKIRYAKU
# 235                 NIHONKIRYAKU
# 259          SHIN-SENZAI-WAKASHU
# 260                 MOROZANE-SHU
# 283           ZOKU-GOSEN-WAKASHU
# 294                      CHUYUKI
# 381   TSUKIMOUDE-WAKASHU(PART-3)
# 389                 SHUGYOKU-SHU
# 400            INOKUMA-KAMPAKUKI
# 415             JUNTOKUIN-GYOSHU
# 418             JUNTOKUIN-GYOSHU
# 420                    SHUI-GUSO
# 422               MITSUTSUNE-SHU
# 435               SHIIBA-WAKASHU
# 464                   TAMEIE-SHU
# 467                   TAMEIE-SHU
# 468                ZOKU-SHIGUSHO
# 470          DAINAGON-TAMEIE-SHU
# 488          NAKANOTSUKASA-NIKKI
# 500                 SANEMI-KYOKI
# 523         HANAZONOTENNO-SHINKI
# 529                RINEI-WAKASHU
# 646                     SOKONSHU
# 652                     SOKONSHU
# 653                     SOKONSHU
# 673               ENROKUCHOKASHU
# 733       GONARAIN-GYOSEI-BASSHO
# 791              TOKITSUNE-KYOKI
# 839                   KYOHAKUSHU
# 860          BURUI-GENYO-WAKASHU
# 1045                  TEIEN-EISO
# 1062                  YATAKA-SHU

# %% [markdown]
# ## Graph the full-flowering date (DOY) over time

# %%
df['Full-flowering date (DOY)'].hist()

# %% [markdown]
# ## 15. Smooth out the graph
#
# It's so jagged! You can use `df.rolling` to calculate a rolling average.
#
# The following code calculates a **10-year mean**, using the `AD` column as the anchor. If there aren't 20 samples to work with in a row, it'll accept down to 5. Neat, right?
#
# (We're only looking at the final 5)

# %%
##########################################################################
df.rolling(20, on='AD', min_periods=5).mean().tail()
# If this gives you an error you're using an old pandas version,
# so you can use df.set_index('AD').rolling(10, min_periods=5).mean().reset_index().tail()
# instead
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  \
# 1210  2011                      96.45               406.20
# 1211  2012                      96.80               406.55
# 1212  2013                      96.60               406.35
# 1213  2014                      96.35               406.10
# 1214  2015                      96.05               405.80
#
#                                       Source code          Data type code  \
# 1210  ound after the last publication of articles  data from modern times
# 1211  ound after the last publication of articles  data from modern times
# 1212  ound after the last publication of articles  data from modern times
# 1213  ound after the last publication of articles  data from modern times
# 1214  ound after the last publication of articles  data from modern times
#
#               Reference Name
# 1210  NEWS-PAPER(ARASHIYAMA)
# 1211  NEWS-PAPER(ARASHIYAMA)
# 1212  NEWS-PAPER(ARASHIYAMA)
# 1213  NEWS-PAPER(ARASHIYAMA)
# 1214  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# Adjust the code above to compute **and graph** a 20-year rolling average for the entire dataset.

# %%
df.rolling(20, on='AD', min_periods=5).mean().hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11484b7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1149270f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11496fcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1149eb4a8>]], dtype=object)

# %% [markdown]
# # Adding a month column
#
# ### HOLD ON, time to learn something
#
# **There are a few ways to do the next question**, but a couple popular methods will have pandas yell at you. You might want to try this new thing called `loc`! **It is used to update a column in a row based on a condition.**
#
# ```
# df.loc[df.country == 'Angola', "continent"] = "Africa"
# ```
#
# This updates the `continent` column to be `Africa` for every row where `df.country == 'Angola'`. You CANNOT do the following, which is probably what you've wanted to do:
#
# ```
# df[df.country == 'Angola']['continent'] = 'Africa'
# ```
#
# And now you know.
#
# ### Actually adding our column
#
# Right now the "Full-flowering date" column is pretty rough. It uses numbers like '402' to mean "April 2nd" and "416" to mean "April 16th." Let's make a column to explain what month it happened in.
#
# * Every row that happened in April should have 'April' in the `month` column.
# * Every row that happened in March should have 'March' as the `month` column.
# * Every row that happened in May should have 'May' as the `month` column.

# %%
#import re
#df.loc[df['Full-flowering date'] == "4*", :]

#df['Full-flowering date']
#df
#df.loc[df['Full-flowering date'].str.contains("^4"), 'month'] 
#df.head()

df.dtypes
# Out:
# AD                             int64
# Full-flowering date (DOY)    float64
# Full-flowering date          float64
# Source code                   object
# Data type code                object
# Reference Name                object
# month                           bool
# dtype: object

# %%
#This is what I used in Corporate Prosecutions to create a new column (year) based on information given from
#the date column. I don't understand why I can't create a month column based on extracting the first 2 digits 
#in the Full-flowering date column... and then replacing the digits by their corresponding months( 4 - April, etc.)
#My guess it has something to do with the float vs. string, but I don't know how to con
df['Month'] = df['Full-flowering date'].str.extract("^/d{2}.*")
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-40d59201f25d> in <module>()
# ----> 1 df['Month'] = df['Full-flowering date'].str.extract("^/d{2}.*")
#       2 df
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3075         if (name in self._internal_names_set or name in self._metadata or
#    3076                 name in self._accessors):
# -> 3077             return object.__getattribute__(self, name)
#    3078         else:
#    3079             if name in self._info_axis:
#
# /usr/local/lib/python3.6/site-packages/pandas/core/base.py in __get__(self, instance, owner)
#     241             # this ensures that Series.str.<method> is well defined
#     242             return self.accessor_cls
# --> 243         return self.construct_accessor(instance)
#     244
#     245     def __set__(self, instance, value):
#
# /usr/local/lib/python3.6/site-packages/pandas/core/strings.py in _make_str_accessor(self)
#    1907             # (instead of test for object dtype), but that isn't practical for
#    1908             # performance reasons until we have a str dtype (GH 9343)
# -> 1909             raise AttributeError("Can only use .str accessor with string "
#    1910                                  "values, which use np.object_ dtype in "
#    1911                                  "pandas")
#
# AttributeError: Can only use .str accessor with string values, which use np.object_ dtype in pandas

# %% [markdown]
# ### Using your new column, how many blossomings happened in each month?

# %% [markdown]
# ### Graph how many blossomings happened in each month.

# %% [markdown]
# ## 19. Adding a day-of-month column
#
# Now we're going to add a new column called **day-of-month** based on the full-flowering date.
#
# - 402 means "April 2"
# - 312 means "March 12"
# - 511 means "May 11"
#
# **We're only interested in the second part**. Previously I've had students convert them to integers to do this, but you know regular expressions!
#
# - Tip: You won't be able to extract anything from a float, you'll need it to be a string
# - Tip: There are two things that mean "talk about this column as a string," maybe you want me to talk about them?

# %%
df1['e'] = Series(np.random.randn(sLength), index=df1.index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-d97a57507b0a> in <module>()
# ----> 1 df1['e'] = Series(np.random.randn(sLength), index=df1.index)
#
# NameError: name 'Series' is not defined

# %% [markdown]
# Now that you've successfully extracted the last two letters, save them into a new column called `'day-of-month'`

# %% [markdown]
# ### 20. Adding a date column
#
# Now take the `'month'` and `'day-of-month'` columns and combine them in order to create a new column called `'date'`. If should look like "April 09".
